# %%
import os
from load_dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.prompts import ChatPromptTemplate

from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import JSONLoader
from langchain_community.embeddings import OpenAIEmbeddings

from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda, RunnablePassthrough

from langchain_openai import ChatOpenAI, OpenAIEmbeddings

embedding_function = OpenAIEmbeddings()

loader = JSONLoader(file_path="../data/Coca_cola.json", jq_schema=".prizes[]", text_content=False)
documents = loader.load()

db = Chroma.from_documents(documents, embedding_function)
retriever = db.as_retriever()

template = """Answer the question based only on the following context:
{context}

Question: {question}£
"""
prompt = ChatPromptTemplate.from_template(template)

model = ChatOpenAI()

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

query = "What year did albert einstein win the nobel prize?"
print(chain.invoke(query))
# Out:
# Albert Einstein won the Nobel Prize in Physics in the year 1921.

# %%
loader = JSONLoader(file_path="../data/Coca_cola.json",  jq_schema="{}",text_content=True)
documents = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 loader = JSONLoader(file_path="../data/Coca_cola.json",  jq_schema="{}",text_content=True)
# ----> 2 documents = loader.load()
#
# File c:\Users\ZENBOOK\anaconda3\envs\finance_repo\lib\site-packages\langchain_core\document_loaders\base.py:30, in BaseLoader.load(self)
#      28 def load(self) -> List[Document]:
#      29     """Load data into Document objects."""
# ---> 30     return list(self.lazy_load())
#
# File c:\Users\ZENBOOK\anaconda3\envs\finance_repo\lib\site-packages\langchain_community\document_loaders\json_loader.py:146, in JSONLoader.lazy_load(self)
#     144                     index += 1
#     145 else:
# --> 146     for doc in self._parse(self.file_path.read_text(encoding="utf-8"), index):
#     147         yield doc
#     148         index += 1
#
# ...

# %%
import json
# Opening JSON file
f = open("../data/prize.json")

# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
data["prizes"][0]
# Out:
# {'year': '2023',
#  'category': 'chemistry',
#  'laureates': [{'id': '1029',
#    'firstname': 'Moungi',
#    'surname': 'Bawendi',
#    'motivation': '"for the discovery and synthesis of quantum dots"',
#    'share': '3'},
#   {'id': '1030',
#    'firstname': 'Louis',
#    'surname': 'Brus',
#    'motivation': '"for the discovery and synthesis of quantum dots"',
#    'share': '3'},
#   {'id': '1031',
#    'firstname': 'Aleksey',
#    'surname': 'Yekimov',
#    'motivation': '"for the discovery and synthesis of quantum dots"',
#    'share': '3'}]}
